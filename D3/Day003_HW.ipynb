# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %% [markdown]
# ### 1: File I/O

# %%
fh = open("/Users/tommy84729/python/1st-PyCrawlerMarathon/D3/example/64_72hr_CH.xml", "r")
xml = fh.read()
fh.close()
#print(xml)

# %% [markdown]
# ### 2 : xmltodict

# %%
import xmltodict
d = dict(xmltodict.parse(xml))

# %%
datasetDescription = d['cwbopendata']['dataset']['datasetInfo']['datasetDescription']
print(datasetDescription)
# Out:
# 臺灣各縣市鄉鎮未來3天(72小時)逐3小時天氣預報

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ## 1. 請問高雄市有多少地區有溫度資料？

# %%
with open('/Users/tommy84729/python/1st-PyCrawlerMarathon/D3/example/64_72hr_CH.xml') as fd:
    doc = dict(xmltodict.parse(fd.read()))

# %%
len(doc['cwbopendata']['dataset']['locations']['location'])
# Out:
# 38

# %%
doc1 = doc['cwbopendata']['dataset']['locations']['location']
for i in range(len(doc1)) : 
    k = doc1[i]
    print(k['locationName'])
# Out:
# 鹽埕區
# 鼓山區
# 左營區
# 楠梓區
# 三民區
# 新興區
# 前金區
# 苓雅區
# 前鎮區
# 旗津區
# 小港區
# 鳳山區
# 林園區
# 大寮區
# 大樹區
# 大社區
# 仁武區
# 鳥松區
# 岡山區
# 橋頭區
# 燕巢區
# 田寮區
# 阿蓮區
# 路竹區
# 湖內區
# 茄萣區
# 永安區
# 彌陀區
# 梓官區
# 旗山區
# 美濃區
# 六龜區
# 甲仙區
# 杉林區
# 內門區
# 茂林區
# 桃源區
# 那瑪夏區

# %% [markdown]
# ### 有38個地區擁有溫度資料

# %% [markdown]
# ## 2.請取出每一個地區所記錄的第一個時間點跟溫度

# %%
for i in range(len(doc1)) : 
    a = doc1[i]
    b = a['weatherElement'][0]['time'][0] 
    print(b['dataTime'] ,' ' ,b['elementValue']['value'])
# Out:
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   32
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   32
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   35
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   32
# 2019-06-28T12:00:00+08:00   32
# 2019-06-28T12:00:00+08:00   32
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   33
# 2019-06-28T12:00:00+08:00   36
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   34
# 2019-06-28T12:00:00+08:00   31
# 2019-06-28T12:00:00+08:00   29

# %% [markdown]
# ## 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
c = doc1[0]['weatherElement'][0]['time'][0]
print(c['dataTime'] , '' , c['elementValue']['value'])
# Out:
# 2019-06-28T12:00:00+08:00  33
