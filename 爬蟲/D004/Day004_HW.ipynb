# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text

# %%
type(r.text)
# Out:
# str

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10998396594',
#   'type': 'PushEvent',
#   'actor': {'id': 131186,
#    'login': 'dchaplinsky',
#    'display_login': 'dchaplinsky',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dchaplinsky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/131186?'},
#   'repo': {'id': 30988270,
#    'name': 'dchaplinsky/pep.org.ua',
#    'url': 'https://api.github.com/repos/dchaplinsky/pep.org.ua'},
#   'payload': {'push_id': 4348352776,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a7c4d2248793b1a320d3f5d29d58e0a330645541',
#    'before': '91f39db7d93774529acf1b27746fe901ce971706',
#    'commits': [{'sha': 'a7c4d2248793b1a320d3f5d29d58e0a330645541',
#      'author': {'email': 'dchaplinsky@conversionscience.co.uk',
#       'name': 'Dmitry Chaplinsky'},
#      'message': 'Fixing country pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dchaplinsky/pep.org.ua/commits/a7c4d2248793b1a320d3f5d29d58e0a330645541'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396600',
#   'type': 'PushEvent',
#   'actor': {'id': 55827253,
#    'login': 'AlexBorodulina',
#    'display_login': 'AlexBorodulina',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AlexBorodulina',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55827253?'},
#   'repo': {'id': 225144257,
#    'name': 'AlexBorodulina/2.2.3_GameOfLife',
#    'url': 'https://api.github.com/repos/AlexBorodulina/2.2.3_GameOfLife'},
#   'payload': {'push_id': 4348352774,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '656873e2836d7be4671db7cd2024734f255dcb62',
#    'before': 'b12de8f8410a305e153d8873347488dc2295712d',
#    'commits': [{'sha': '656873e2836d7be4671db7cd2024734f255dcb62',
#      'author': {'email': '55827253+AlexBorodulina@users.noreply.github.com',
#       'name': 'AlexBorodulina'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AlexBorodulina/2.2.3_GameOfLife/commits/656873e2836d7be4671db7cd2024734f255dcb62'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396599',
#   'type': 'WatchEvent',
#   'actor': {'id': 17881109,
#    'login': 'onelivesleft',
#    'display_login': 'onelivesleft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/onelivesleft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17881109?'},
#   'repo': {'id': 51753808,
#    'name': 'pragmagic/vscode-nim',
#    'url': 'https://api.github.com/repos/pragmagic/vscode-nim'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z',
#   'org': {'id': 8536602,
#    'login': 'pragmagic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pragmagic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8536602?'}},
#  {'id': '10998396589',
#   'type': 'PushEvent',
#   'actor': {'id': 38099353,
#    'login': 'IMLHF',
#    'display_login': 'IMLHF',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IMLHF',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38099353?'},
#   'repo': {'id': 219717206,
#    'name': 'IMLHF/se_relative_loss',
#    'url': 'https://api.github.com/repos/IMLHF/se_relative_loss'},
#   'payload': {'push_id': 4348352777,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '326741f1f9ccc60c2ddb136aa4d2902c8878c45c',
#    'before': '56934d46f7b8194a3bb56e651d110e17fea84376',
#    'commits': [{'sha': '326741f1f9ccc60c2ddb136aa4d2902c8878c45c',
#      'author': {'email': 'red_wind@foxmail.com', 'name': 'IMLHF'},
#      'message': 'save mask',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/IMLHF/se_relative_loss/commits/326741f1f9ccc60c2ddb136aa4d2902c8878c45c'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396585',
#   'type': 'PushEvent',
#   'actor': {'id': 49432089,
#    'login': 'RomanKashik',
#    'display_login': 'RomanKashik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RomanKashik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49432089?'},
#   'repo': {'id': 224863561,
#    'name': 'RomanKashik/ecommerce',
#    'url': 'https://api.github.com/repos/RomanKashik/ecommerce'},
#   'payload': {'push_id': 4348352766,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Roman',
#    'head': 'd2d8a513573f431d220f5a298f5b385202201429',
#    'before': 'aad73047ad49c7c6123bf9fc83a9afb8a2a8622c',
#    'commits': [{'sha': '5c83114a04942cbd07b4cc22fca784f503348ef4',
#      'author': {'email': 'kashik.roman@rambler.ru', 'name': 'Roman Kashik'},
#      'message': 'Merge pull request #1 from RomanKashik/Roman\n\nSecond commit',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/RomanKashik/ecommerce/commits/5c83114a04942cbd07b4cc22fca784f503348ef4'},
#     {'sha': 'b40207d845c5398b5761e41a8393946774b5fcba',
#      'author': {'email': 'kashik.roman@rambler.ru', 'name': 'Roman Kashik'},
#      'message': 'Merge pull request #2 from RomanKashik/Roman\n\nRoman',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/RomanKashik/ecommerce/commits/b40207d845c5398b5761e41a8393946774b5fcba'},
#     {'sha': 'd2d8a513573f431d220f5a298f5b385202201429',
#      'author': {'email': 'kashik.roman@rambler.ru', 'name': 'Roman'},
#      'message': "Merge branch 'master' into Roman",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RomanKashik/ecommerce/commits/d2d8a513573f431d220f5a298f5b385202201429'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396588',
#   'type': 'PushEvent',
#   'actor': {'id': 35837643,
#    'login': 'fw-ops',
#    'display_login': 'fw-ops',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fw-ops',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35837643?'},
#   'repo': {'id': 49911655,
#    'name': 'FIWARE-GEs/cosmos.flink',
#    'url': 'https://api.github.com/repos/FIWARE-GEs/cosmos.flink'},
#   'payload': {'push_id': 4348352769,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e68eff0570ff859dd1f9632310501c946d1c6f8a',
#    'before': '74ce143c5c362d403a47e84c1c9cdf3537f8b030',
#    'commits': [{'sha': 'e68eff0570ff859dd1f9632310501c946d1c6f8a',
#      'author': {'email': '42933957+Javierlj@users.noreply.github.com',
#       'name': 'Javierlj'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FIWARE-GEs/cosmos.flink/commits/e68eff0570ff859dd1f9632310501c946d1c6f8a'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z',
#   'org': {'id': 44202370,
#    'login': 'FIWARE-GEs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FIWARE-GEs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44202370?'}},
#  {'id': '10998396586',
#   'type': 'ForkEvent',
#   'actor': {'id': 51071010,
#    'login': 'hongfanmeng',
#    'display_login': 'hongfanmeng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hongfanmeng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51071010?'},
#   'repo': {'id': 175036357,
#    'name': 'paldier/softcenterarm',
#    'url': 'https://api.github.com/repos/paldier/softcenterarm'},
#   'payload': {'forkee': {'id': 225598072,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU1OTgwNzI=',
#     'name': 'softcenterarm',
#     'full_name': 'hongfanmeng/softcenterarm',
#     'private': False,
#     'owner': {'login': 'hongfanmeng',
#      'id': 51071010,
#      'node_id': 'MDQ6VXNlcjUxMDcxMDEw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/51071010?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/hongfanmeng',
#      'html_url': 'https://github.com/hongfanmeng',
#      'followers_url': 'https://api.github.com/users/hongfanmeng/followers',
#      'following_url': 'https://api.github.com/users/hongfanmeng/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hongfanmeng/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/hongfanmeng/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hongfanmeng/subscriptions',
#      'organizations_url': 'https://api.github.com/users/hongfanmeng/orgs',
#      'repos_url': 'https://api.github.com/users/hongfanmeng/repos',
#      'events_url': 'https://api.github.com/users/hongfanmeng/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/hongfanmeng/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/hongfanmeng/softcenterarm',
#     'description': 'softcenter for armv7l（bcm47xx）',
#     'fork': True,
#     'url': 'https://api.github.com/repos/hongfanmeng/softcenterarm',
#     'forks_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/forks',
#     'keys_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/teams',
#     'hooks_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/hooks',
#     'issue_events_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/events',
#     'assignees_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/tags',
#     'blobs_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/languages',
#     'stargazers_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/stargazers',
#     'contributors_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/contributors',
#     'subscribers_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/subscribers',
#     'subscription_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/subscription',
#     'commits_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/merges',
#     'archive_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/downloads',
#     'issues_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/hongfanmeng/softcenterarm/deployments',
#     'created_at': '2019-12-03T10:57:34Z',
#     'updated_at': '2019-12-03T10:57:30Z',
#     'pushed_at': '2019-11-17T13:53:11Z',
#     'git_url': 'git://github.com/hongfanmeng/softcenterarm.git',
#     'ssh_url': 'git@github.com:hongfanmeng/softcenterarm.git',
#     'clone_url': 'https://github.com/hongfanmeng/softcenterarm.git',
#     'svn_url': 'https://github.com/hongfanmeng/softcenterarm',
#     'homepage': '',
#     'size': 539448,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396551',
#   'type': 'IssuesEvent',
#   'actor': {'id': 35923697,
#    'login': 'ni-fara',
#    'display_login': 'ni-fara',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ni-fara',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35923697?'},
#   'repo': {'id': 15428480,
#    'name': 'ColorlibHQ/AdminLTE',
#    'url': 'https://api.github.com/repos/ColorlibHQ/AdminLTE'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/ColorlibHQ/AdminLTE/issues/2431',
#     'repository_url': 'https://api.github.com/repos/ColorlibHQ/AdminLTE',
#     'labels_url': 'https://api.github.com/repos/ColorlibHQ/AdminLTE/issues/2431/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ColorlibHQ/AdminLTE/issues/2431/comments',
#     'events_url': 'https://api.github.com/repos/ColorlibHQ/AdminLTE/issues/2431/events',
#     'html_url': 'https://github.com/ColorlibHQ/AdminLTE/issues/2431',
#     'id': 531900027,
#     'node_id': 'MDU6SXNzdWU1MzE5MDAwMjc=',
#     'number': 2431,
#     'title': "[BUG] Drag and drop feature doesn't work on mobile",
#     'user': {'login': 'ni-fara',
#      'id': 35923697,
#      'node_id': 'MDQ6VXNlcjM1OTIzNjk3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/35923697?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ni-fara',
#      'html_url': 'https://github.com/ni-fara',
#      'followers_url': 'https://api.github.com/users/ni-fara/followers',
#      'following_url': 'https://api.github.com/users/ni-fara/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ni-fara/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ni-fara/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ni-fara/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ni-fara/orgs',
#      'repos_url': 'https://api.github.com/users/ni-fara/repos',
#      'events_url': 'https://api.github.com/users/ni-fara/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ni-fara/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 72086672,
#       'node_id': 'MDU6TGFiZWw3MjA4NjY3Mg==',
#       'url': 'https://api.github.com/repos/ColorlibHQ/AdminLTE/labels/type:bug',
#       'name': 'type:bug',
#       'color': 'fc2929',
#       'default': False,
#       'description': ''},
#      {'id': 281690670,
#       'node_id': 'MDU6TGFiZWwyODE2OTA2NzA=',
#       'url': 'https://api.github.com/repos/ColorlibHQ/AdminLTE/labels/version:3.x',
#       'name': 'version:3.x',
#       'color': '9319a7',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-03T10:57:34Z',
#     'updated_at': '2019-12-03T10:57:34Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "**Describe the bug**\r\nThere is a To Do List in Dashbord v1, it's items has a drag and drop feature on desktop using mouse pointer but on mobile you can't use this feature with touch screen.\r\n\r\n**Expected behavior**\r\nOn mobile version may be touching the item for a few seconds let the user to move the item of the list.\r\n\r\n**Environment (please complete the following information):**\r\n - AdminLTE Version: 3"}},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z',
#   'org': {'id': 39128121,
#    'login': 'ColorlibHQ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ColorlibHQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39128121?'}},
#  {'id': '10998396527',
#   'type': 'PushEvent',
#   'actor': {'id': 47348890,
#    'login': 'SFP010',
#    'display_login': 'SFP010',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SFP010',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47348890?'},
#   'repo': {'id': 208229928,
#    'name': 'Suzan79/Project-C',
#    'url': 'https://api.github.com/repos/Suzan79/Project-C'},
#   'payload': {'push_id': 4348352744,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd44ba14065709b84db0125d7aab50ae6544481d2',
#    'before': '2f39d46a8518946cff526640d178e00272d88d34',
#    'commits': [{'sha': 'd44ba14065709b84db0125d7aab50ae6544481d2',
#      'author': {'email': 'Spoot@hotmail.nl', 'name': 'Poot'},
#      'message': 'Made the search results title smaller',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Suzan79/Project-C/commits/d44ba14065709b84db0125d7aab50ae6544481d2'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396526',
#   'type': 'PushEvent',
#   'actor': {'id': 52466746,
#    'login': 'EmailMessaging',
#    'display_login': 'EmailMessaging',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EmailMessaging',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52466746?'},
#   'repo': {'id': 197720213,
#    'name': 'EmailMessaging/EmailMessaging.github.io',
#    'url': 'https://api.github.com/repos/EmailMessaging/EmailMessaging.github.io'},
#   'payload': {'push_id': 4348352748,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fe708115b2f7c90d8e95d54aa2c8f01b52ba8f05',
#    'before': '5d4ee836a91642e52679b15f4ea4433ee9a50c0f',
#    'commits': [{'sha': 'fe708115b2f7c90d8e95d54aa2c8f01b52ba8f05',
#      'author': {'email': 'nadeem.butt@bt.com', 'name': 'Nadeem Butt'},
#      'message': 'zip updated',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EmailMessaging/EmailMessaging.github.io/commits/fe708115b2f7c90d8e95d54aa2c8f01b52ba8f05'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396528',
#   'type': 'PushEvent',
#   'actor': {'id': 58385389,
#    'login': 'qkd0863',
#    'display_login': 'qkd0863',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qkd0863',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58385389?'},
#   'repo': {'id': 225592362,
#    'name': 'qkd0863/ossw_2019',
#    'url': 'https://api.github.com/repos/qkd0863/ossw_2019'},
#   'payload': {'push_id': 4348352750,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f99d750bf2e3a96c2d44df61411ae8a426315aca',
#    'before': 'bdf2de133a60eda1806e960519b5832830dba5d9',
#    'commits': [{'sha': 'f99d750bf2e3a96c2d44df61411ae8a426315aca',
#      'author': {'email': '58385389+qkd0863@users.noreply.github.com',
#       'name': 'qkd0863'},
#      'message': 'Create 2018180022.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/qkd0863/ossw_2019/commits/f99d750bf2e3a96c2d44df61411ae8a426315aca'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396525',
#   'type': 'PushEvent',
#   'actor': {'id': 13835601,
#    'login': 'disha00991',
#    'display_login': 'disha00991',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/disha00991',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13835601?'},
#   'repo': {'id': 216214222,
#    'name': 'disha00991/webume',
#    'url': 'https://api.github.com/repos/disha00991/webume'},
#   'payload': {'push_id': 4348352745,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'df8dd28f6655207d73dc2f0a05fcfede0b6602e9',
#    'before': 'e0475e3965028d678327f078b5cbd0adeb4397f3',
#    'commits': [{'sha': 'df8dd28f6655207d73dc2f0a05fcfede0b6602e9',
#      'author': {'email': 'disha@thb.co.in', 'name': 'dishasingh'},
#      'message': 'Updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/disha00991/webume/commits/df8dd28f6655207d73dc2f0a05fcfede0b6602e9'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396529',
#   'type': 'ForkEvent',
#   'actor': {'id': 4104649,
#    'login': 'monnster',
#    'display_login': 'monnster',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/monnster',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4104649?'},
#   'repo': {'id': 24410210,
#    'name': 'JetBrains/swot',
#    'url': 'https://api.github.com/repos/JetBrains/swot'},
#   'payload': {'forkee': {'id': 225598069,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU1OTgwNjk=',
#     'name': 'swot',
#     'full_name': 'monnster/swot',
#     'private': False,
#     'owner': {'login': 'monnster',
#      'id': 4104649,
#      'node_id': 'MDQ6VXNlcjQxMDQ2NDk=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/4104649?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/monnster',
#      'html_url': 'https://github.com/monnster',
#      'followers_url': 'https://api.github.com/users/monnster/followers',
#      'following_url': 'https://api.github.com/users/monnster/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/monnster/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/monnster/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/monnster/subscriptions',
#      'organizations_url': 'https://api.github.com/users/monnster/orgs',
#      'repos_url': 'https://api.github.com/users/monnster/repos',
#      'events_url': 'https://api.github.com/users/monnster/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/monnster/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/monnster/swot',
#     'description': 'Identify email addresses or domains names that belong to colleges or universities. Help automate the process of approving or rejecting academic discounts.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/monnster/swot',
#     'forks_url': 'https://api.github.com/repos/monnster/swot/forks',
#     'keys_url': 'https://api.github.com/repos/monnster/swot/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/monnster/swot/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/monnster/swot/teams',
#     'hooks_url': 'https://api.github.com/repos/monnster/swot/hooks',
#     'issue_events_url': 'https://api.github.com/repos/monnster/swot/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/monnster/swot/events',
#     'assignees_url': 'https://api.github.com/repos/monnster/swot/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/monnster/swot/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/monnster/swot/tags',
#     'blobs_url': 'https://api.github.com/repos/monnster/swot/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/monnster/swot/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/monnster/swot/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/monnster/swot/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/monnster/swot/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/monnster/swot/languages',
#     'stargazers_url': 'https://api.github.com/repos/monnster/swot/stargazers',
#     'contributors_url': 'https://api.github.com/repos/monnster/swot/contributors',
#     'subscribers_url': 'https://api.github.com/repos/monnster/swot/subscribers',
#     'subscription_url': 'https://api.github.com/repos/monnster/swot/subscription',
#     'commits_url': 'https://api.github.com/repos/monnster/swot/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/monnster/swot/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/monnster/swot/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/monnster/swot/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/monnster/swot/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/monnster/swot/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/monnster/swot/merges',
#     'archive_url': 'https://api.github.com/repos/monnster/swot/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/monnster/swot/downloads',
#     'issues_url': 'https://api.github.com/repos/monnster/swot/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/monnster/swot/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/monnster/swot/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/monnster/swot/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/monnster/swot/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/monnster/swot/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/monnster/swot/deployments',
#     'created_at': '2019-12-03T10:57:34Z',
#     'updated_at': '2019-12-02T13:30:33Z',
#     'pushed_at': '2019-12-03T07:42:03Z',
#     'git_url': 'git://github.com/monnster/swot.git',
#     'ssh_url': 'git@github.com:monnster/swot.git',
#     'clone_url': 'https://github.com/monnster/swot.git',
#     'svn_url': 'https://github.com/monnster/swot',
#     'homepage': '',
#     'size': 19013,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z',
#   'org': {'id': 878437,
#    'login': 'JetBrains',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/JetBrains',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/878437?'}},
#  {'id': '10998396503',
#   'type': 'PushEvent',
#   'actor': {'id': 2293252,
#    'login': 'HanKruiger',
#    'display_login': 'HanKruiger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HanKruiger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2293252?'},
#   'repo': {'id': 175458586,
#    'name': 'simonscheider/SemanticPipelines',
#    'url': 'https://api.github.com/repos/simonscheider/SemanticPipelines'},
#   'payload': {'push_id': 4348352733,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/han/python3',
#    'head': 'dc2b720023019d153aa0412386d4a8cc41c92e23',
#    'before': 'ead41f9beef304da0c41790c433495abb4b9f564',
#    'commits': [{'sha': 'dc2b720023019d153aa0412386d4a8cc41c92e23',
#      'author': {'email': 'hankruiger@gmail.com', 'name': 'HanKruiger'},
#      'message': 'Normalized tool descriptions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/simonscheider/SemanticPipelines/commits/dc2b720023019d153aa0412386d4a8cc41c92e23'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z'},
#  {'id': '10998396510',
#   'type': 'CreateEvent',
#   'actor': {'id': 58468874,
#    'login': 'RyoIkuta',
#    'display_login': 'RyoIkuta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RyoIkuta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58468874?'},
#   'repo': {'id': 225598070,
#    'name': 'RyoIkuta/iot',
#    'url': 'https://api.github.com/repos/RyoIkuta/iot'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'iot',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396504',
#   'type': 'PushEvent',
#   'actor': {'id': 51477572,
#    'login': 'szilagyiadam',
#    'display_login': 'szilagyiadam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/szilagyiadam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51477572?'},
#   'repo': {'id': 190720115,
#    'name': 'szilagyiadam/jerryscript',
#    'url': 'https://api.github.com/repos/szilagyiadam/jerryscript'},
#   'payload': {'push_id': 4348352730,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/symbol_unscopables',
#    'head': 'b67db5734b710eb6bf3dc038b81c8668990e8efb',
#    'before': '3dd59450b7732719026ff6437e9998edfdf8e6f2',
#    'commits': [{'sha': 'b67db5734b710eb6bf3dc038b81c8668990e8efb',
#      'author': {'email': 'aszilagy@inf.u-szeged.hu', 'name': 'Adam Szilagyi'},
#      'message': 'Implement Symbol.unscopables\n\nAdded a new property for Array.prototype based on ECMA-262 v6, 22.1.3.31\nAlso upgraded the HasBinding operation with ECMA-262 v6, 8.1.1.2.1 steps 7-9\n\nJerryScript-DCO-1.0-Signed-off-by: Adam Szilagyi aszilagy@inf.u-szeged.hu',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/szilagyiadam/jerryscript/commits/b67db5734b710eb6bf3dc038b81c8668990e8efb'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z'},
#  {'id': '10998396507',
#   'type': 'PushEvent',
#   'actor': {'id': 8505069,
#    'login': 'cmen',
#    'display_login': 'cmen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cmen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8505069?'},
#   'repo': {'id': 42778912,
#    'name': 'cmen/CMENGoogleChartsBundle',
#    'url': 'https://api.github.com/repos/cmen/CMENGoogleChartsBundle'},
#   'payload': {'push_id': 4348352738,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ci',
#    'head': '4538a20be43a2e346e2f4599b8763e38175cc781',
#    'before': '93fe68521b31e7bd8e436748c49025de61ccb55a',
#    'commits': [{'sha': '4538a20be43a2e346e2f4599b8763e38175cc781',
#      'author': {'email': 'cmen@users.noreply.github.com',
#       'name': 'Christophe Meneses'},
#      'message': 'Continuous integration workflow',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cmen/CMENGoogleChartsBundle/commits/4538a20be43a2e346e2f4599b8763e38175cc781'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:35Z'},
#  {'id': '10998396494',
#   'type': 'PushEvent',
#   'actor': {'id': 6077461,
#    'login': 'moritzbuck',
#    'display_login': 'moritzbuck',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/moritzbuck',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6077461?'},
#   'repo': {'id': 212041811,
#    'name': 'moritzbuck/0039_mOTUlizer',
#    'url': 'https://api.github.com/repos/moritzbuck/0039_mOTUlizer'},
#   'payload': {'push_id': 4348352725,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/dev',
#    'head': '2c072c7e26ef92ab2132d88adf4bb01701198a6c',
#    'before': '5fd47fa87ff6709a25f04850e8d95056efd94e28',
#    'commits': [{'sha': '473f37e9be404c523294a1cba462116de168d531',
#      'author': {'email': 'moritz@rackham3.uppmax.uu.se', 'name': 'moritzbuck'},
#      'message': 'not sure what I did',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/moritzbuck/0039_mOTUlizer/commits/473f37e9be404c523294a1cba462116de168d531'},
#     {'sha': '2c072c7e26ef92ab2132d88adf4bb01701198a6c',
#      'author': {'email': 'moritz@rackham3.uppmax.uu.se', 'name': 'moritzbuck'},
#      'message': 'fixed merged',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/moritzbuck/0039_mOTUlizer/commits/2c072c7e26ef92ab2132d88adf4bb01701198a6c'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z'},
#  {'id': '10998396493',
#   'type': 'PushEvent',
#   'actor': {'id': 3137192,
#    'login': 'gildniy',
#    'display_login': 'gildniy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gildniy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3137192?'},
#   'repo': {'id': 216529789,
#    'name': 'andela/boondocks-bn-backend',
#    'url': 'https://api.github.com/repos/andela/boondocks-bn-backend'},
#   'payload': {'push_id': 4348352722,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/bg-fix-profile-comments-tests-170071511',
#    'head': 'c5016eb4860c5bf934f30d8ba48b76fde1dd080c',
#    'before': '01178693a8acc7d0f35a2968d01eb0928781ebe1',
#    'commits': [{'sha': 'c5016eb4860c5bf934f30d8ba48b76fde1dd080c',
#      'author': {'email': 'gildniy05@gmail.com', 'name': 'Gildas Niyigena'},
#      'message': ' bug(tests) fix profile and comments tests\n - Tests for profile and comments no longer cause other tests to fail.\n[Finishes #169257416]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andela/boondocks-bn-backend/commits/c5016eb4860c5bf934f30d8ba48b76fde1dd080c'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z',
#   'org': {'id': 4100206,
#    'login': 'andela',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/andela',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4100206?'}},
#  {'id': '10998396492',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 740361,
#    'login': 'heyakyra',
#    'display_login': 'heyakyra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/heyakyra',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/740361?'},
#   'repo': {'id': 57167764,
#    'name': 'xi-editor/xi-editor',
#    'url': 'https://api.github.com/repos/xi-editor/xi-editor'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/xi-editor/xi-editor/issues/302',
#     'repository_url': 'https://api.github.com/repos/xi-editor/xi-editor',
#     'labels_url': 'https://api.github.com/repos/xi-editor/xi-editor/issues/302/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/xi-editor/xi-editor/issues/302/comments',
#     'events_url': 'https://api.github.com/repos/xi-editor/xi-editor/issues/302/events',
#     'html_url': 'https://github.com/xi-editor/xi-editor/issues/302',
#     'id': 229520468,
#     'node_id': 'MDU6SXNzdWUyMjk1MjA0Njg=',
#     'number': 302,
#     'title': 'key bindings + modal editing (vim) discussion',
#     'user': {'login': 'cmyr',
#      'id': 3330916,
#      'node_id': 'MDQ6VXNlcjMzMzA5MTY=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/3330916?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cmyr',
#      'html_url': 'https://github.com/cmyr',
#      'followers_url': 'https://api.github.com/users/cmyr/followers',
#      'following_url': 'https://api.github.com/users/cmyr/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cmyr/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cmyr/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cmyr/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cmyr/orgs',
#      'repos_url': 'https://api.github.com/users/cmyr/repos',
#      'events_url': 'https://api.github.com/users/cmyr/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cmyr/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 607996947,
#       'node_id': 'MDU6TGFiZWw2MDc5OTY5NDc=',
#       'url': 'https://api.github.com/repos/xi-editor/xi-editor/labels/discussion',
#       'name': 'discussion',
#       'color': 'a379c7',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 57,
#     'created_at': '2017-05-18T00:07:39Z',
#     'updated_at': '2019-12-03T10:57:34Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'body': "I want to capture some stuff from IRC earlier today, about approaches to vim-mode/modal editing more generally. The kindling question was from @theduke, who asked, _should the core have a concept of key bindings?_\r\n\r\nThe more general question is: how should key bindings be handled, and what is the division of labour between core and client, here?\r\n\r\nSome general take-aways:\r\n\r\n- _How important is lossless vim emulation, versus enabling **vim-like** functionality_? For instance: Vim does not let you navigate to the position after the last character on a line. These feels like a hangover from the hardware terminal days. Is this desired behaviour?\r\n\r\n- _vim mode_ is itself less important than general 'modal' support, which could be implemented by a state machine that exists in core, consuming raw key events and outputting editor events.\r\n\r\n- This feature should exist alongside the current system for handling events; the user would be able to opt-in via some setting.\r\n\r\n- The client should (could) have some flag that toggles between `raw_input` and `selector` mode; this flag might be set by core in the course of editting; when in `raw_mode` the client would be expected to just send raw keystrokes. `selector` mode would maintain the current behaviour.\r\n\r\n- integration with [IME](https://en.wikipedia.org/wiki/Input_method) is tricky, because the client needs to know the core mode in order to correctly dispatch keypresses. For instance (with future vim emulation enabled, and the editor in command mode) if we type `ika<return>` on a japanese input method, we would want `i` to be interpreted as 'insert mode', and `ka` to be passed through to the input method for 'か'. Does this mean that keypresses have to be sync? Some subset of keypresses? Should there be some other mechanism?\r\n\r\n- this gets to be more fun if you're in 'replace' mode.\r\n\r\n- The lazy option is to not support IME when using the editor modally.\r\n\r\n- This raises the larger question of what is the role of core, and what is the role of the client. Contributors who have been more heavily involved in writing clients (@sp3d, @eyelash) are more skeptical of whether core can offer a good solution here.\r\n\r\n\r\nIf anyone thinks I missed anything or has anything else to add, let me know. 😄 \r\n\r\nrelevant: #93 #291 \r\n\r\n"},
#    'comment': {'url': 'https://api.github.com/repos/xi-editor/xi-editor/issues/comments/561115213',
#     'html_url': 'https://github.com/xi-editor/xi-editor/issues/302#issuecomment-561115213',
#     'issue_url': 'https://api.github.com/repos/xi-editor/xi-editor/issues/302',
#     'id': 561115213,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MTExNTIxMw==',
#     'user': {'login': 'heyakyra',
#      'id': 740361,
#      'node_id': 'MDQ6VXNlcjc0MDM2MQ==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/740361?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/heyakyra',
#      'html_url': 'https://github.com/heyakyra',
#      'followers_url': 'https://api.github.com/users/heyakyra/followers',
#      'following_url': 'https://api.github.com/users/heyakyra/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/heyakyra/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/heyakyra/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/heyakyra/subscriptions',
#      'organizations_url': 'https://api.github.com/users/heyakyra/orgs',
#      'repos_url': 'https://api.github.com/users/heyakyra/repos',
#      'events_url': 'https://api.github.com/users/heyakyra/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/heyakyra/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-03T10:57:34Z',
#     'updated_at': '2019-12-03T10:57:34Z',
#     'author_association': 'NONE',
#     'body': 'A fellow non-querty user here (started with Colemak but now use Dvorak) would also appreciate Kak mode to satisfy this ticket. Is there already a ticket for handling multiple cursors/selections? What else is needed for `XiVi` to act like Kakoune?'}},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z',
#   'org': {'id': 43351123,
#    'login': 'xi-editor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/xi-editor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43351123?'}},
#  {'id': '10998396486',
#   'type': 'PushEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 221863580,
#    'name': 'metauro/swagger',
#    'url': 'https://api.github.com/repos/metauro/swagger'},
#   'payload': {'push_id': 4348352717,
#    'size': 44,
#    'distinct_size': 15,
#    'ref': 'refs/heads/master',
#    'head': '7877b4e035b7f28160194fc5b38fa0715d9ba749',
#    'before': '3f13f11dd96f4786537ea2f222318972858296c8',
#    'commits': [{'sha': '26157646addacfb8b83a169ee3520db75a6e4e50',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'refactor() the overall codebase refactor',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/26157646addacfb8b83a169ee3520db75a6e4e50'},
#     {'sha': '932d79b61b0ba461f6902dfddfd4bbe2ffe47899',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'feat() add name param to ApiModelProperty',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/932d79b61b0ba461f6902dfddfd4bbe2ffe47899'},
#     {'sha': '57ced5fe16654af50e4edf521b749ee722ca6990',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'ci() add unit and e2e tests',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/57ced5fe16654af50e4edf521b749ee722ca6990'},
#     {'sha': '4e18b2399db71093ad120c955ab4b432b6c7fd11',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'refactor() remove api file decorator',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/4e18b2399db71093ad120c955ab4b432b6c7fd11'},
#     {'sha': '36ee9d66f0fb9eafceb88e64d702bbac1cca3f13',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'ci() fix indention',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/36ee9d66f0fb9eafceb88e64d702bbac1cca3f13'},
#     {'sha': 'a695d33893bbd91e2dfc9c90495f44de977e9f72',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'ci() fix jobs syntax',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/a695d33893bbd91e2dfc9c90495f44de977e9f72'},
#     {'sha': 'b868c77c88c0acb13a92aea25805807346cab65b',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'test() add small fixes',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/b868c77c88c0acb13a92aea25805807346cab65b'},
#     {'sha': '0d35bcc24cc5d32aca16014a0ff6b40825c0e6dd',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'feat() add extra models feature, add plugin',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/0d35bcc24cc5d32aca16014a0ff6b40825c0e6dd'},
#     {'sha': '2f539b944c2a1e728747757e6dcd6b5dbc488417',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'chore() bump version',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/2f539b944c2a1e728747757e6dcd6b5dbc488417'},
#     {'sha': 'ddc6066cb93fca842527bcd7c48579f2fc52632b',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'resolve conflicts',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/ddc6066cb93fca842527bcd7c48579f2fc52632b'},
#     {'sha': 'ff704c535006384e6d72d39ad5b9d9381dbfefd5',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'ci() fix package-lock file',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/ff704c535006384e6d72d39ad5b9d9381dbfefd5'},
#     {'sha': 'a0fda8b6d7cf99176674261d3e2bd90addb9fc14',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Mysliwiec'},
#      'message': 'Merge pull request #355 from nestjs/refactor/major\n\nrefactor() the overall codebase refactor WIP',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/a0fda8b6d7cf99176674261d3e2bd90addb9fc14'},
#     {'sha': '7fb2bb90be9a00c2e8fc26565b2a7ef629a4ce32',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'fix() add missing properties support (response model)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/7fb2bb90be9a00c2e8fc26565b2a7ef629a4ce32'},
#     {'sha': 'b987fb5ae050f6009560b177e69a12319e4b64bc',
#      'author': {'email': 'ctch5@mail.umsl.edu', 'name': 'Chau Tran'},
#      'message': 'fix schema for nested schema',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/b987fb5ae050f6009560b177e69a12319e4b64bc'},
#     {'sha': '2ad68dd174a0411f4bf5034e69d5e4e9ce9d80cc',
#      'author': {'email': 'ctch5@mail.umsl.edu', 'name': 'Chau Tran'},
#      'message': 'fix test',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/2ad68dd174a0411f4bf5034e69d5e4e9ce9d80cc'},
#     {'sha': '869861f6130364d89bf6959393829b7d230dda1e',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Mysliwiec'},
#      'message': 'Merge pull request #370 from nartc/fix-schema\n\nfix(next): fix nested schema',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/869861f6130364d89bf6959393829b7d230dda1e'},
#     {'sha': '3d4bcccd7bdf250342df23a321c978261b3b960a',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'chore() publish 4.0.0-next.2',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/3d4bcccd7bdf250342df23a321c978261b3b960a'},
#     {'sha': '38af63e043d4b591ae0d610710d990b5f7ebae64',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Mysliwiec'},
#      'message': 'Merge pull request #371 from nestjs/refactor/major\n\nfix() add missing properties support (response model)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/38af63e043d4b591ae0d610710d990b5f7ebae64'},
#     {'sha': '0642dc5395c587d6f69805078c38e5747a50946c',
#      'author': {'email': 'mail@kamilmysliwiec.com', 'name': 'Kamil Myśliwiec'},
#      'message': 'chore() publish 4.0.0-next.3',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/0642dc5395c587d6f69805078c38e5747a50946c'},
#     {'sha': '38b768b4948935b6cc547e0f1fd2e0eb687e5bc7',
#      'author': {'email': 'loban@vrify.com', 'name': 'Loban Rahman'},
#      'message': 'Modify test-case to expose bug that @ApiOperation cannot handle lazy-evaluated-type-function\n\n@see https://github.com/nestjs/swagger/issues/374',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/metauro/swagger/commits/38b768b4948935b6cc547e0f1fd2e0eb687e5bc7'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z'},
#  {'id': '10998396480',
#   'type': 'PushEvent',
#   'actor': {'id': 6229665,
#    'login': 'thomiz',
#    'display_login': 'thomiz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thomiz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6229665?'},
#   'repo': {'id': 193045383,
#    'name': 'HL7Norway/Grunndata-profiles',
#    'url': 'https://api.github.com/repos/HL7Norway/Grunndata-profiles'},
# ...
#        'events_url': 'https://api.github.com/users/FanchCapel/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/FanchCapel/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/FanchCapel/Ginger',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/FanchCapel/Ginger',
#       'forks_url': 'https://api.github.com/repos/FanchCapel/Ginger/forks',
#       'keys_url': 'https://api.github.com/repos/FanchCapel/Ginger/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/FanchCapel/Ginger/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/FanchCapel/Ginger/teams',
#       'hooks_url': 'https://api.github.com/repos/FanchCapel/Ginger/hooks',
#       'issue_events_url': 'https://api.github.com/repos/FanchCapel/Ginger/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/FanchCapel/Ginger/events',
#       'assignees_url': 'https://api.github.com/repos/FanchCapel/Ginger/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/FanchCapel/Ginger/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/FanchCapel/Ginger/tags',
#       'blobs_url': 'https://api.github.com/repos/FanchCapel/Ginger/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/FanchCapel/Ginger/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/FanchCapel/Ginger/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/FanchCapel/Ginger/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/FanchCapel/Ginger/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/FanchCapel/Ginger/languages',
#       'stargazers_url': 'https://api.github.com/repos/FanchCapel/Ginger/stargazers',
#       'contributors_url': 'https://api.github.com/repos/FanchCapel/Ginger/contributors',
#       'subscribers_url': 'https://api.github.com/repos/FanchCapel/Ginger/subscribers',
#       'subscription_url': 'https://api.github.com/repos/FanchCapel/Ginger/subscription',
#       'commits_url': 'https://api.github.com/repos/FanchCapel/Ginger/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/FanchCapel/Ginger/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/FanchCapel/Ginger/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/FanchCapel/Ginger/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/FanchCapel/Ginger/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/FanchCapel/Ginger/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/FanchCapel/Ginger/merges',
#       'archive_url': 'https://api.github.com/repos/FanchCapel/Ginger/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/FanchCapel/Ginger/downloads',
#       'issues_url': 'https://api.github.com/repos/FanchCapel/Ginger/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/FanchCapel/Ginger/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/FanchCapel/Ginger/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/FanchCapel/Ginger/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/FanchCapel/Ginger/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/FanchCapel/Ginger/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/FanchCapel/Ginger/deployments',
#       'created_at': '2019-11-25T14:40:28Z',
#       'updated_at': '2019-12-03T09:29:59Z',
#       'pushed_at': '2019-12-03T10:56:34Z',
#       'git_url': 'git://github.com/FanchCapel/Ginger.git',
#       'ssh_url': 'git@github.com:FanchCapel/Ginger.git',
#       'clone_url': 'https://github.com/FanchCapel/Ginger.git',
#       'svn_url': 'https://github.com/FanchCapel/Ginger',
#       'homepage': None,
#       'size': 20243,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/FanchCapel/Ginger/pulls/70'},
#      'html': {'href': 'https://github.com/FanchCapel/Ginger/pull/70'},
#      'issue': {'href': 'https://api.github.com/repos/FanchCapel/Ginger/issues/70'},
#      'comments': {'href': 'https://api.github.com/repos/FanchCapel/Ginger/issues/70/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/FanchCapel/Ginger/pulls/70/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/FanchCapel/Ginger/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/FanchCapel/Ginger/pulls/70/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/FanchCapel/Ginger/statuses/b05af387cd371e725a34beacf42a7075f57bd230'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 319,
#     'deletions': 32,
#     'changed_files': 20}},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z'},
#  {'id': '10998396456',
#   'type': 'PushEvent',
#   'actor': {'id': 40120264,
#    'login': 'Sanmopre',
#    'display_login': 'Sanmopre',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sanmopre',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40120264?'},
#   'repo': {'id': 214364976,
#    'name': 'Sanmopre/DESARROLLO',
#    'url': 'https://api.github.com/repos/Sanmopre/DESARROLLO'},
#   'payload': {'push_id': 4348352707,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '693134abf3b25ea5c735de3f0f3ae1bbc8a48139',
#    'before': 'a3984904c4a73c728bf3447961fdba16654c9037',
#    'commits': [{'sha': '693134abf3b25ea5c735de3f0f3ae1bbc8a48139',
#      'author': {'email': '40120264+Sanmopre@users.noreply.github.com',
#       'name': 'Sanmopre'},
#      'message': 'h',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sanmopre/DESARROLLO/commits/693134abf3b25ea5c735de3f0f3ae1bbc8a48139'}]},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z'},
#  {'id': '10998396470',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 12383899,
#    'login': 'Avasil',
#    'display_login': 'Avasil',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Avasil',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12383899?'},
#   'repo': {'id': 68894798,
#    'name': 'monix/monix-kafka',
#    'url': 'https://api.github.com/repos/monix/monix-kafka'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/monix/monix-kafka/issues/128',
#     'repository_url': 'https://api.github.com/repos/monix/monix-kafka',
#     'labels_url': 'https://api.github.com/repos/monix/monix-kafka/issues/128/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/monix/monix-kafka/issues/128/comments',
#     'events_url': 'https://api.github.com/repos/monix/monix-kafka/issues/128/events',
#     'html_url': 'https://github.com/monix/monix-kafka/issues/128',
#     'id': 502165858,
#     'node_id': 'MDU6SXNzdWU1MDIxNjU4NTg=',
#     'number': 128,
#     'title': 'How to detect KafkaProducerSink failures?',
#     'user': {'login': 'yeryomenkom',
#      'id': 12167141,
#      'node_id': 'MDQ6VXNlcjEyMTY3MTQx',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/12167141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/yeryomenkom',
#      'html_url': 'https://github.com/yeryomenkom',
#      'followers_url': 'https://api.github.com/users/yeryomenkom/followers',
#      'following_url': 'https://api.github.com/users/yeryomenkom/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/yeryomenkom/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/yeryomenkom/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/yeryomenkom/subscriptions',
#      'organizations_url': 'https://api.github.com/users/yeryomenkom/orgs',
#      'repos_url': 'https://api.github.com/users/yeryomenkom/repos',
#      'events_url': 'https://api.github.com/users/yeryomenkom/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/yeryomenkom/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1597516661,
#       'node_id': 'MDU6TGFiZWwxNTk3NTE2NjYx',
#       'url': 'https://api.github.com/repos/monix/monix-kafka/labels/scala-spree',
#       'name': 'scala-spree',
#       'color': '006b75',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 9,
#     'created_at': '2019-10-03T16:21:22Z',
#     'updated_at': '2019-12-03T10:57:34Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'Hi!\r\nI use the same approach for producing kafka records that is described in the documentation:\r\n```\r\nval producer = KafkaProducerSink[String,String](producerCfg, scheduler)\r\n\r\n// Lets pretend we have this observable of records\r\nval observable: Observable[ProducerRecord[???,???]] = ???\r\n\r\nobservable\r\n  // on overflow, start dropping incoming events\r\n  .whileBusyDrop\r\n  // buffers into batches if the consumer is busy, up to a max size\r\n  .bufferIntrospective(1024)\r\n  // consume everything by pushing into Apache Kafka\r\n  .consumeWith(producer)\r\n  // ready, set, go!\r\n  .runToFuture\r\n```\r\n\r\nBut, in case if serialization error occurs, the `Future` object that I get from the `runToFuture` method completes without any failure. Such behavior looks strange to me. \r\nI am not a very experienced user of monix. So, maybe I am doing something wrong. \r\n\r\nThank you for your help!)\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/monix/monix-kafka/issues/comments/561115212',
#     'html_url': 'https://github.com/monix/monix-kafka/issues/128#issuecomment-561115212',
#     'issue_url': 'https://api.github.com/repos/monix/monix-kafka/issues/128',
#     'id': 561115212,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MTExNTIxMg==',
#     'user': {'login': 'Avasil',
#      'id': 12383899,
#      'node_id': 'MDQ6VXNlcjEyMzgzODk5',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/12383899?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Avasil',
#      'html_url': 'https://github.com/Avasil',
#      'followers_url': 'https://api.github.com/users/Avasil/followers',
#      'following_url': 'https://api.github.com/users/Avasil/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Avasil/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Avasil/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Avasil/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Avasil/orgs',
#      'repos_url': 'https://api.github.com/users/Avasil/repos',
#      'events_url': 'https://api.github.com/users/Avasil/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Avasil/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-03T10:57:34Z',
#     'updated_at': '2019-12-03T10:57:34Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'Thank you @fdilg :)'}},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z',
#   'org': {'id': 16490874,
#    'login': 'monix',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/monix',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16490874?'}},
#  {'id': '10998396454',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 54840628,
#    'login': 'elehtine',
#    'display_login': 'elehtine',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elehtine',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54840628?'},
#   'repo': {'id': 218538339,
#    'name': 'elehtine/tetris',
#    'url': 'https://api.github.com/repos/elehtine/tetris'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/elehtine/tetris/releases/21924354',
#     'assets_url': 'https://api.github.com/repos/elehtine/tetris/releases/21924354/assets',
#     'upload_url': 'https://uploads.github.com/repos/elehtine/tetris/releases/21924354/assets{?name,label}',
#     'html_url': 'https://github.com/elehtine/tetris/releases/tag/viikko5',
#     'id': 21924354,
#     'node_id': 'MDc6UmVsZWFzZTIxOTI0MzU0',
#     'tag_name': 'viikko5',
#     'target_commitish': 'master',
#     'name': 'Viikon 5 deadline',
#     'draft': False,
#     'author': {'login': 'elehtine',
#      'id': 54840628,
#      'node_id': 'MDQ6VXNlcjU0ODQwNjI4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/54840628?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/elehtine',
#      'html_url': 'https://github.com/elehtine',
#      'followers_url': 'https://api.github.com/users/elehtine/followers',
#      'following_url': 'https://api.github.com/users/elehtine/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/elehtine/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/elehtine/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/elehtine/subscriptions',
#      'organizations_url': 'https://api.github.com/users/elehtine/orgs',
#      'repos_url': 'https://api.github.com/users/elehtine/repos',
#      'events_url': 'https://api.github.com/users/elehtine/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/elehtine/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'prerelease': False,
#     'created_at': '2019-12-03T09:47:47Z',
#     'published_at': '2019-12-03T10:57:34Z',
#     'assets': [{'url': 'https://api.github.com/repos/elehtine/tetris/releases/assets/16560718',
#       'id': 16560718,
#       'node_id': 'MDEyOlJlbGVhc2VBc3NldDE2NTYwNzE4',
#       'name': 'tetris.jar',
#       'label': None,
#       'uploader': {'login': 'elehtine',
#        'id': 54840628,
#        'node_id': 'MDQ6VXNlcjU0ODQwNjI4',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/54840628?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/elehtine',
#        'html_url': 'https://github.com/elehtine',
#        'followers_url': 'https://api.github.com/users/elehtine/followers',
#        'following_url': 'https://api.github.com/users/elehtine/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/elehtine/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/elehtine/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/elehtine/subscriptions',
#        'organizations_url': 'https://api.github.com/users/elehtine/orgs',
#        'repos_url': 'https://api.github.com/users/elehtine/repos',
#        'events_url': 'https://api.github.com/users/elehtine/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/elehtine/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'content_type': 'application/x-java-archive',
#       'state': 'uploaded',
#       'size': 8254968,
#       'download_count': 0,
#       'created_at': '2019-12-03T10:56:17Z',
#       'updated_at': '2019-12-03T10:57:34Z',
#       'browser_download_url': 'https://github.com/elehtine/tetris/releases/download/viikko5/tetris.jar'}],
#     'tarball_url': 'https://api.github.com/repos/elehtine/tetris/tarball/viikko5',
#     'zipball_url': 'https://api.github.com/repos/elehtine/tetris/zipball/viikko5',
#     'body': ''}},
#   'public': True,
#   'created_at': '2019-12-03T10:57:34Z'}]

# %%
type(json.loads(r.text))
# Out:
# list

# %% [markdown]
# ### 可以看到json和r.text的差異在於讀取出來資料形態的不同，r.text為字串，而json則是list或著是dict

# %% [markdown]
# ## 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ## 選擇starwars的API

# %%
r1 = requests.get('https://swapi.co/api/people')
json.loads(r1.text)
# Out:
# {'count': 87,
#  'next': 'https://swapi.co/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/',
#     'https://swapi.co/api/films/7/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': ['https://swapi.co/api/vehicles/14/',
#     'https://swapi.co/api/vehicles/30/'],
#    'starships': ['https://swapi.co/api/starships/12/',
#     'https://swapi.co/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.co/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
#    'skin_color': 'gold',
#    'eye_color': 'yellow',
#    'birth_year': '112BBY',
#    'gender': 'n/a',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/5/',
#     'https://swapi.co/api/films/4/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/'],
#    'species': ['https://swapi.co/api/species/2/'],
#    'vehicles': [],
#    'starships': [],
#    'created': '2014-12-10T15:10:51.357000Z',
#    'edited': '2014-12-20T21:17:50.309000Z',
#    'url': 'https://swapi.co/api/people/2/'},
#   {'name': 'R2-D2',
#    'height': '96',
#    'mass': '32',
#    'hair_color': 'n/a',
#    'skin_color': 'white, blue',
#    'eye_color': 'red',
#    'birth_year': '33BBY',
#    'gender': 'n/a',
#    'homeworld': 'https://swapi.co/api/planets/8/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/5/',
#     'https://swapi.co/api/films/4/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/',
#     'https://swapi.co/api/films/7/'],
#    'species': ['https://swapi.co/api/species/2/'],
#    'vehicles': [],
#    'starships': [],
#    'created': '2014-12-10T15:11:50.376000Z',
#    'edited': '2014-12-20T21:17:50.311000Z',
#    'url': 'https://swapi.co/api/people/3/'},
#   {'name': 'Darth Vader',
#    'height': '202',
#    'mass': '136',
#    'hair_color': 'none',
#    'skin_color': 'white',
#    'eye_color': 'yellow',
#    'birth_year': '41.9BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': [],
#    'starships': ['https://swapi.co/api/starships/13/'],
#    'created': '2014-12-10T15:18:20.704000Z',
#    'edited': '2014-12-20T21:17:50.313000Z',
#    'url': 'https://swapi.co/api/people/4/'},
#   {'name': 'Leia Organa',
#    'height': '150',
#    'mass': '49',
#    'hair_color': 'brown',
#    'skin_color': 'light',
#    'eye_color': 'brown',
#    'birth_year': '19BBY',
#    'gender': 'female',
#    'homeworld': 'https://swapi.co/api/planets/2/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/',
#     'https://swapi.co/api/films/7/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': ['https://swapi.co/api/vehicles/30/'],
#    'starships': [],
#    'created': '2014-12-10T15:20:09.791000Z',
#    'edited': '2014-12-20T21:17:50.315000Z',
#    'url': 'https://swapi.co/api/people/5/'},
#   {'name': 'Owen Lars',
#    'height': '178',
#    'mass': '120',
#    'hair_color': 'brown, grey',
#    'skin_color': 'light',
#    'eye_color': 'blue',
#    'birth_year': '52BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/5/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/1/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': [],
#    'starships': [],
#    'created': '2014-12-10T15:52:14.024000Z',
#    'edited': '2014-12-20T21:17:50.317000Z',
#    'url': 'https://swapi.co/api/people/6/'},
#   {'name': 'Beru Whitesun lars',
#    'height': '165',
#    'mass': '75',
#    'hair_color': 'brown',
#    'skin_color': 'light',
#    'eye_color': 'blue',
#    'birth_year': '47BBY',
#    'gender': 'female',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/5/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/1/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': [],
#    'starships': [],
#    'created': '2014-12-10T15:53:41.121000Z',
#    'edited': '2014-12-20T21:17:50.319000Z',
#    'url': 'https://swapi.co/api/people/7/'},
#   {'name': 'R5-D4',
#    'height': '97',
#    'mass': '32',
#    'hair_color': 'n/a',
#    'skin_color': 'white, red',
#    'eye_color': 'red',
#    'birth_year': 'unknown',
#    'gender': 'n/a',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/1/'],
#    'species': ['https://swapi.co/api/species/2/'],
#    'vehicles': [],
#    'starships': [],
#    'created': '2014-12-10T15:57:50.959000Z',
#    'edited': '2014-12-20T21:17:50.321000Z',
#    'url': 'https://swapi.co/api/people/8/'},
#   {'name': 'Biggs Darklighter',
#    'height': '183',
#    'mass': '84',
#    'hair_color': 'black',
#    'skin_color': 'light',
#    'eye_color': 'brown',
#    'birth_year': '24BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/1/',
#    'films': ['https://swapi.co/api/films/1/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': [],
#    'starships': ['https://swapi.co/api/starships/12/'],
#    'created': '2014-12-10T15:59:50.509000Z',
#    'edited': '2014-12-20T21:17:50.323000Z',
#    'url': 'https://swapi.co/api/people/9/'},
#   {'name': 'Obi-Wan Kenobi',
#    'height': '182',
#    'mass': '77',
#    'hair_color': 'auburn, white',
#    'skin_color': 'fair',
#    'eye_color': 'blue-gray',
#    'birth_year': '57BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.co/api/planets/20/',
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/5/',
#     'https://swapi.co/api/films/4/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/',
#     'https://swapi.co/api/films/1/'],
#    'species': ['https://swapi.co/api/species/1/'],
#    'vehicles': ['https://swapi.co/api/vehicles/38/'],
#    'starships': ['https://swapi.co/api/starships/48/',
#     'https://swapi.co/api/starships/59/',
#     'https://swapi.co/api/starships/64/',
#     'https://swapi.co/api/starships/65/',
#     'https://swapi.co/api/starships/74/'],
#    'created': '2014-12-10T16:16:29.192000Z',
#    'edited': '2014-12-20T21:17:50.325000Z',
#    'url': 'https://swapi.co/api/people/10/'}]}

# %%
type(json.loads(r1.text))
# Out:
# dict

# %%
for i in range(len(json.loads(r1.text)['results'])) : 
    print(json.loads(r1.text)['results'][i]['name'])
# Out:
# Luke Skywalker
# C-3PO
# R2-D2
# Darth Vader
# Leia Organa
# Owen Lars
# Beru Whitesun lars
# R5-D4
# Biggs Darklighter
# Obi-Wan Kenobi

# %%
for i in range(len(json.loads(r1.text)['results'])) : 
    print(json.loads(r1.text)['results'][i]['height'])
# Out:
# 172
# 167
# 96
# 202
# 150
# 178
# 165
# 97
# 183
# 182
